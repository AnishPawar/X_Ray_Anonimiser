# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("test_img.png")
plt.imshow(img)

# %%
kernel = np.array([[-2,-2,-2], [-2,18,-2], [-2,-2,-2]])
img = cv2.filter2D(img, -1, kernel)
plt.imshow(img)

# %%
cv2.imwrite("Corrected.jpg",img)
# Out:
# True

# %%
img_2 = cv2.imread("X-Ray-Images/Motion_Blur.jpg")
plt.imshow(img_2)

# %%
close_kernel = np.ones((7,7))

canny = cv2.Canny(img_2,200,250)
closing = cv2.morphologyEx(canny,cv2.MORPH_CLOSE,close_kernel)
cv2.imwrite("Canny_Corrected.jpg",closing)
plt.imshow(closing)

# %%
img_2 = cv2.imread("X-Ray-Images/20201206_131615.jpg")

aspect_ratio = img_2.shape[1]/img_2.shape[0]

height = int(500/aspect_ratio)

img_2 = cv2.resize(img_2,(500,height))



print(img_2.shape)

b25 = img_2[int(img_2.shape[0]*0.93):,int(img_2.shape[1]*0.35):int(img_2.shape[1])]
plt.imshow(img_2)
# Out:
# (740, 500, 3)

# %%
var = cv2.Laplacian(img_2, cv2.CV_64F).var()
print(var)
# Out:
# 178.74764156819734

# %%
img_gray = cv2.cvtColor(img_2,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(img_gray,140,255,cv2.THRESH_BINARY_INV)
cv2.imwrite("Canny_Corrected.jpg",thresh)
plt.imshow(thresh)

# %%
import cv2
import matplotlib.pyplot as plt
img_2 = cv2.imread("X-Ray-Images/Viraj_Scan1.jpg")

b25 = img_2[int(img_2.shape[0]*0.93):,int(img_2.shape[1]*0.35):int(img_2.shape[1])]

var = cv2.Sobel(img_2,-1,1,1).var()
print(var)
plt.imshow(img_2)
# Out:
# 36.82452758402163
